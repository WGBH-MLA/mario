# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model_id = "ylacombe/whisper-large-v3-turbo"

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)
# Out:
# WhisperForConditionalGeneration(
#   (model): WhisperModel(
#     (encoder): WhisperEncoder(
#       (conv1): Conv1d(128, 1280, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv2): Conv1d(1280, 1280, kernel_size=(3,), stride=(2,), padding=(1,))
#       (embed_positions): Embedding(1500, 1280)
#       (layers): ModuleList(
#         (0-31): 32 x WhisperEncoderLayer(
#           (self_attn): WhisperSdpaAttention(
#             (k_proj): Linear(in_features=1280, out_features=1280, bias=False)
#             (v_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (q_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (out_proj): Linear(in_features=1280, out_features=1280, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#           (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#           (final_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): WhisperDecoder(
#       (embed_tokens): Embedding(51866, 1280, padding_idx=50257)
#       (embed_positions): WhisperPositionalEmbedding(448, 1280)
#       (layers): ModuleList(
#         (0-3): 4 x WhisperDecoderLayer(
#           (self_attn): WhisperSdpaAttention(
#             (k_proj): Linear(in_features=1280, out_features=1280, bias=False)
#             (v_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (q_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (out_proj): Linear(in_features=1280, out_features=1280, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): WhisperSdpaAttention(
#             (k_proj): Linear(in_features=1280, out_features=1280, bias=False)
#             (v_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (q_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (out_proj): Linear(in_features=1280, out_features=1280, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#           (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#           (final_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (proj_out): Linear(in_features=1280, out_features=51866, bias=False)
# )

# %%
processor = AutoProcessor.from_pretrained(model_id)

# %%
pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    torch_dtype=torch_dtype,
    device=device,
    return_timestamps=True,
)

# %%
result = pipe("audio.mp3")
# Out:
# /Users/ryan_harbert/clams/mario/.venv/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.43.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.

# %%
result
# Out:
# {'text': " Thank you. Thank you. Thank you. She bakes and decorates cakes like no one else. And now, because of a microloan, she has her own business. Our goal is to assist people in low-income communities. What is a microloan? Find out next on In Focus. Thank you. Hello and welcome to In Focus. I'm R.C. Chapa. Tonight we look at a growing movement, microcredit, a program that makes very small loans available to people who want to start their own businesses but have no access to credit through traditional channels. It has proven to be so successful in developing countries that it is now gaining acceptance in industrialized countries as well. Here in New Mexico, four agencies are providing microloans to help reduce poverty. In a moment, we will meet representatives from these organizations. But first, meet a loan recipient who's making the most of her small loan. Karen Castillo's creative genius in cake design, baking, and decoration is immediately apparent to anyone who enters her shop in Rio Bravo Square, a shopping center located in the heart of Albuquerque's South Valley. On the display shelf, visitors can admire some of her creations. Before opening her own business, Karen had perfected her skills over two decades. After graduating from Albuquerque's TBI Baking School in 1978, she was employed by bakeries in New Mexico, California, Arizona, and Nevada. She learned a variety of different techniques and ideas, from the grocery store mass production to the privately owned bakeries that cater to their customers. Karen has been wanting to start her own business since the early 1980s. I would do 40 to 50 wedding cakes on a weekend for another bakery. And I used to think I could do this myself. Karen knew she would someday have her own business because she was bringing in a lot of customers for her employers. but she wasn't able to realize her dream until now for a number of reasons. Well, primarily that she hadn't run a business before and she didn't have any collateral. So it was a completely unproven idea. She had tried with the banks and was unable to obtain funding there. And what we work with is people who are not able to go to the banks. We don't compete with the banks. For those people who can, they should get funding there, and then we can save our capital for people who need it more. Dan Pucetti is a lending coordinator with the New Mexico Community Development Loan Fund, a private nonprofit lender dedicated to the economic empowerment of lower income people. From the beginning I thought she was the kind of person we're here to help. She has a lot of experience. Her product is very good. At our office we buy her cakes all the time. We got turned down twice from different banks and stuff. stuff and I was kind of discouraged but Dan just kept encouraging us. We gave her the application, Karen filled it out, she did put a business plan together explaining where she was going to locate her business, who her clientele was, what her experience was. She told us how much money she wanted, what she needed it for. We took that information, processed it and went to our loan committee and as I said we were able to give her a loan. Karen needed space and equipment. With the loan, she purchased a freezer and two display cases. One of the cases is a rotator that attractively displays her beautiful creations. Her customers come from all over the state, and it's no wonder. Watch how she turns this plain white cake into a work of art. Thank you. I think our cake lady is a success story and it's going to be better. Karen has just gotten started. Her cakes are very good and I know as word of mouth grows, she's going to do extremely well. Joining us this evening to talk more about microlending in New Mexico is Marisa Pereira with Acción New Mexico, Vanjie Gabaldon with the New Mexico Community Development Loan Fund, Agnes Noonan with Westcor, and Senator Jeff Bingaman. Thank you all for joining us. Thank you. Vanjie, I'm going to start with ...
#  'chunks': [{'timestamp': (0.0, 29.98), 'text': ' Thank you.'},
#   {'timestamp': (0.0, 29.98), 'text': ' Thank you.'},
#   {'timestamp': (0.0, 29.98), 'text': ' Thank you.'},
#   {'timestamp': (0.0, 10.56),
#    'text': ' She bakes and decorates cakes like no one else.'},
#   {'timestamp': (10.56, 14.12),
#    'text': ' And now, because of a microloan, she has her own business.'},
#   {'timestamp': (14.62, 18.62),
#    'text': ' Our goal is to assist people in low-income communities.'},
#   {'timestamp': (19.18, 20.2), 'text': ' What is a microloan?'},
#   {'timestamp': (20.74, 22.64), 'text': ' Find out next on In Focus.'},
#   {'timestamp': (0.0, 29.98), 'text': ' Thank you.'},
#   {'timestamp': (0.0, 3.1),
#    'text': " Hello and welcome to In Focus. I'm R.C. Chapa."},
#   {'timestamp': (3.58, 6.68),
#    'text': ' Tonight we look at a growing movement, microcredit,'},
#   {'timestamp': (7.18, 12.54),
#    'text': ' a program that makes very small loans available to people who want to start their own businesses'},
#   {'timestamp': (12.54, 15.78),
#    'text': ' but have no access to credit through traditional channels.'},
#   {'timestamp': (15.78, 19.16),
#    'text': ' It has proven to be so successful in developing countries'},
#   {'timestamp': (19.16, 23.12),
#    'text': ' that it is now gaining acceptance in industrialized countries as well.'},
#   {'timestamp': (23.58, 27.72),
#    'text': ' Here in New Mexico, four agencies are providing microloans to help reduce poverty.'},
#   {'timestamp': (0.0, 3.38),
#    'text': ' In a moment, we will meet representatives from these organizations.'},
#   {'timestamp': (4.02, 8.5),
#    'text': " But first, meet a loan recipient who's making the most of her small loan."},
#   {'timestamp': (10.78, 15.74),
#    'text': " Karen Castillo's creative genius in cake design, baking, and decoration"},
#   {'timestamp': (15.74, 20.54),
#    'text': ' is immediately apparent to anyone who enters her shop in Rio Bravo Square,'},
#   {'timestamp': (21.0, 24.62),
#    'text': " a shopping center located in the heart of Albuquerque's South Valley."},
#   {'timestamp': (0.0, 5.76),
#    'text': ' On the display shelf, visitors can admire some of her creations.'},
#   {'timestamp': (5.76, 12.48),
#    'text': ' Before opening her own business, Karen had perfected her skills over two decades.'},
#   {'timestamp': (12.48, 19.36),
#    'text': " After graduating from Albuquerque's TBI Baking School in 1978, she was employed by bakeries"},
#   {'timestamp': (19.36, 23.52),
#    'text': ' in New Mexico, California, Arizona, and Nevada.'},
#   {'timestamp': (23.52, 28.68),
#    'text': ' She learned a variety of different techniques and ideas, from the grocery store mass production'},
#   {'timestamp': (0.0, 3.6),
#    'text': ' to the privately owned bakeries that cater to their customers.'},
#   {'timestamp': (3.6, 9.06),
#    'text': ' Karen has been wanting to start her own business since the early 1980s.'},
#   {'timestamp': (9.06, 14.72),
#    'text': ' I would do 40 to 50 wedding cakes on a weekend for another bakery.'},
#   {'timestamp': (14.72, 19.42),
#    'text': ' And I used to think I could do this myself.'},
#   {'timestamp': (19.42, 22.16),
#    'text': ' Karen knew she would someday have her own business'},
#   {'timestamp': (22.16, 25.68),
#    'text': ' because she was bringing in a lot of customers for her employers.'},
#   {'timestamp': (0.0, 4.16),
#    'text': " but she wasn't able to realize her dream until now for a number of reasons."},
#   {'timestamp': (4.7, 9.9),
#    'text': " Well, primarily that she hadn't run a business before and she didn't have any collateral."},
#   {'timestamp': (10.74, 12.94),
#    'text': ' So it was a completely unproven idea.'},
#   {'timestamp': (13.46, 16.48),
#    'text': ' She had tried with the banks and was unable to obtain funding there.'},
#   {'timestamp': (17.52, 21.06),
#    'text': ' And what we work with is people who are not able to go to the banks.'},
#   {'timestamp': (21.06, 22.48), 'text': " We don't compete with the banks."},
#   {'timestamp': (23.06, 25.98),
#    'text': ' For those people who can, they should get funding there,'},
#   {'timestamp': (26.08, 28.52),
#    'text': ' and then we can save our capital for people who need it more.'},
#   {'timestamp': (0.0, 5.0),
#    'text': ' Dan Pucetti is a lending coordinator with the New Mexico Community Development Loan Fund,'},
#   {'timestamp': (5.0, 11.0),
#    'text': ' a private nonprofit lender dedicated to the economic empowerment of lower income people.'},
#   {'timestamp': (11.0, 15.0),
#    'text': " From the beginning I thought she was the kind of person we're here to help."},
#   {'timestamp': (15.0, 22.0),
#    'text': ' She has a lot of experience. Her product is very good. At our office we buy her cakes all the time.'},
#   {'timestamp': (22.0, 25.0),
#    'text': ' We got turned down twice from different banks and stuff.'},
#   {'timestamp': (0.0, 6.12),
#    'text': ' stuff and I was kind of discouraged but Dan just kept encouraging us.'},
#   {'timestamp': (6.12, 11.38),
#    'text': ' We gave her the application, Karen filled it out, she did put a business plan together'},
#   {'timestamp': (11.38, 15.52),
#    'text': ' explaining where she was going to locate her business, who her clientele was, what her'},
#   {'timestamp': (15.52, 20.96),
#    'text': ' experience was. She told us how much money she wanted, what she needed it for. We took'},
#   {'timestamp': (20.96, 25.88),
#    'text': ' that information, processed it and went to our loan committee and as I said we were able'},
#   {'timestamp': (25.88, 27.08), 'text': ' to give her a loan.'},
#   {'timestamp': (0.0, 2.72), 'text': ' Karen needed space and equipment.'},
#   {'timestamp': (2.72, 7.0),
#    'text': ' With the loan, she purchased a freezer and two display cases.'},
#   {'timestamp': (7.0, 10.56),
#    'text': ' One of the cases is a rotator that attractively displays'},
#   {'timestamp': (10.56, 12.92), 'text': ' her beautiful creations.'},
#   {'timestamp': (12.92, 17.44),
#    'text': " Her customers come from all over the state, and it's no wonder."},
#   {'timestamp': (17.44, 21.72),
#    'text': ' Watch how she turns this plain white cake into a work of art.'},
#   {'timestamp': (0.0, 29.98), 'text': ' Thank you.'},
#   {'timestamp': (0.0, 15.0),
#    'text': " I think our cake lady is a success story and it's going to be better."},
#   {'timestamp': (15.0, 17.52), 'text': ' Karen has just gotten started.'},
#   {'timestamp': (17.52, 23.32),
#    'text': " Her cakes are very good and I know as word of mouth grows, she's going to do extremely"},
#   {'timestamp': (23.32, 26.88), 'text': ' well.'},
#   {'timestamp': (0.0, 4.64),
#    'text': ' Joining us this evening to talk more about microlending in New Mexico is Marisa Pereira'},
#   {'timestamp': (4.64, 9.76),
#    'text': ' with Acción New Mexico, Vanjie Gabaldon with the New Mexico Community Development Loan'},
#   {'timestamp': (9.76, 14.64),
#    'text': ' Fund, Agnes Noonan with Westcor, and Senator Jeff Bingaman.'},
#   {'timestamp': (14.64, 15.64), 'text': ' Thank you all for joining us.'},
#   {'timestamp': (15.64, 16.64), 'text': ' Thank you.'},
#   {'timestamp': (16.64, 20.26),
#    'text': " Vanjie, I'm going to start with you since Karen is one of your clients."},
#   {'timestamp': (20.26, 21.86),
#    'text': " Is she the kind of client you're looking for?"},
#   {'timestamp': (21.86, 25.06),
#    'text': ' What is your criteria when you do lend money?'},
#   {'timestamp': (0.0, 7.46),
#    'text': ' And Castillo is certainly a client that fits the makeup of a client we would recruit to the loan fund.'},
#   {'timestamp': (9.02, 15.74),
#    'text': ' Our criteria is individuals who are looking to start a business or who have a business'},
#   {'timestamp': (15.74, 19.14),
#    'text': ' who either employ low-income people or who are low-income themselves,'},
#   {'timestamp': (19.38, 28.56),
#    'text': ' who have had a very tough time or an impossible time accessing credit from any traditional source of funding'},
#   {'timestamp': (0.0, 6.24),
#    'text': ' like banks or credit unions. Karen came to us because she had this dream of'},
#   {'timestamp': (6.24, 10.08),
#    'text': ' starting her own business and she had had the dream for a long time. She was'},
#   {'timestamp': (10.08, 13.44),
#    'text': ' making money for a lot of other people making those beautiful kicks she makes'},
#   {'timestamp': (13.44, 18.24),
#    'text': ' and she wanted to to find a way to sustain herself to support herself and'},
#   {'timestamp': (18.24, 22.44),
#    'text': ' she had gone to the banks and the banks had turned her down for a variety of'},
#   {'timestamp': (22.44, 27.18),
#    'text': ' reasons. It was a risky venture. She had had some credit problems in the past and'},
#   {'timestamp': (0.0, 1.08), 'text': ' And we worked with her.'},
#   {'timestamp': (1.08, 4.7),
#    'text': ' We found out what the reason was for her credit problems, and we approved the loan.'},
#   {'timestamp': (4.7, 5.7), 'text': " And she's in business."},
#   {'timestamp': (5.7, 6.7), 'text': " She's doing well."},
#   {'timestamp': (6.7, 11.5),
#    'text': " She's doing incredible stuff, and she's got a market for her product."},
#   {'timestamp': (11.5, 14.32),
#    'text': ' Well, now, I know she is in the South Valley.'},
#   {'timestamp': (14.32, 16.24),
#    'text': ' Is that the area you mostly focus on?'},
#   {'timestamp': (16.24, 17.98), 'text': " No, we're a statewide lender."},
#   {'timestamp': (17.98, 23.22),
#    'text': ' We do have a program that is specifically to serve the South Valley because there is'},
#   {'timestamp': (23.22, 28.6),
#    'text': ' a great need in the South Valley for additional economic activity.'},
#   {'timestamp': (0.0, 4.82),
#    'text': ' Well, we are a statewide lender, so we serve the entire state, primarily rural areas of'},
#   {'timestamp': (4.82, 10.96),
#    'text': ' New Mexico, and in the urban area of Albuquerque and Las Cruces, we really focus on the low'},
#   {'timestamp': (10.96, 15.24),
#    'text': ' income communities within the urban areas, the pocket of poverty communities.'},
#   {'timestamp': (15.24, 16.24), 'text': ' Okay.'},
#   {'timestamp': (16.24, 19.44),
#    'text': ' Marisa, what about AXIO New Mexico?'},
#   {'timestamp': (19.44, 20.44), 'text': ' What is your mission?'},
#   {'timestamp': (20.44, 21.44), 'text': ' Sure.'},
#   {'timestamp': (21.44, 26.72),
#    'text': ' Our mission is to provide entrepreneurs in the Albuquerque area with the credit and training'},
#   {'timestamp': (0.0, 4.62),
#    'text': ' that they really need to pursue a dream of success as an entrepreneur.'},
#   {'timestamp': (4.62, 8.18),
#    'text': " In some cases it may be a start-up business, maybe that's been run out of the home as a"},
#   {'timestamp': (8.18, 9.18), 'text': ' hobby.'},
#   {'timestamp': (9.18, 14.4),
#    'text': " It may be a storefront on a deserted street corner that they're trying to bring back to"},
#   {'timestamp': (14.4, 16.28), 'text': ' life here in Albuquerque.'},
#   {'timestamp': (16.28, 21.72),
#    'text': ' But I think the common thread with our clients is that they have energy and drive and vision'},
#   {'timestamp': (21.72, 27.44),
#    'text': ' to succeed, but what may be lacking is just the know-how to put that to work most effectively'},
#   {'timestamp': (0.0, 2.4), 'text': ' and the capital to fuel that dream.'},
#   {'timestamp': (2.6, 5.94),
#    'text': ' So we provide those loans, and hopefully with the loan,'},
#   {'timestamp': (6.0, 10.0),
#    'text': ' the entrepreneur can become a catalyst for positive change in their neighborhood.'},
#   {'timestamp': (10.24, 12.96),
#    'text': ' When you say capital, what kind of capital are we talking about?'},
#   {'timestamp': (12.96, 16.12),
#    'text': ' We provide loans anywhere from $200,000 to $50,000'},
#   {'timestamp': (16.12, 20.48),
#    'text': ' to people within 20 miles of Albuquerque city limits.'},
#   {'timestamp': (21.82, 22.46), 'text': ' Yes?'},
#   {'timestamp': (22.64, 23.06), 'text': ' Go ahead.'},
#   {'timestamp': (23.42, 26.22),
#    'text': ' The loans are offered on a stepped basis,'},
#   {'timestamp': (26.4, 29.66),
#    'text': " so someone's first loan with us has a ceiling on it."},
#   {'timestamp': (0.0, 3.64),
#    'text': " You can apply up to a certain amount based on how many years you've been in business"},
#   {'timestamp': (3.64, 4.94), 'text': " or if you're a startup."},
#   {'timestamp': (5.48, 9.06),
#    'text': " And it's an attempt for someone to really get off on the best foot with the business."},
#   {'timestamp': (9.2, 13.26),
#    'text': ' We want to make sure that the loan is manageable so that it can be put to good use.'},
#   {'timestamp': (13.58, 16.6),
#    'text': ' And from there, people can apply for whatever amount they feel is appropriate.'},
#   {'timestamp': (17.08, 21.32),
#    'text': ' What is your success rate with people actually paying back their loans?'},
#   {'timestamp': (21.5, 21.88), 'text': ' Sure.'},
#   {'timestamp': (22.32, 25.4),
#    'text': ' Our default rate right now is less than 2%,'},
#   {'timestamp': (25.4, 28.24),
#    'text': ' which is actually very competitive with a commercial bank.'},
#   {'timestamp': (0.0, 7.2),
#    'text': ' But you need to keep in mind that these are clients who, for whatever reason, have not been able to qualify at a local bank for a loan.'},
#   {'timestamp': (7.56, 10.02),
#    'text': ' A lot of times it may be because of a lack of income.'},
#   {'timestamp': (10.66, 12.6),
#    'text': ' It may be because of a lack of a track record.'},
#   {'timestamp': (12.74, 18.28),
#    'text': ' For a startup business, it can be very challenging to access capital under the business name.'},
#   {'timestamp': (18.4, 22.28),
#    'text': ' Some people will have to finance a business off their credit cards, for instance.'},
#   {'timestamp': (22.48, 25.28),
#    'text': ' And those are the people who can qualify for credit cards.'},
#   {'timestamp': (25.32, 26.48), 'text': " As you know, that's not everybody."},
#   {'timestamp': (0.0, 5.0),
#    'text': ' Okay, Agnes, I want to talk to you about your organization, Westcore.'},
#   {'timestamp': (5.0, 8.0),
#    'text': " You're the Executive Director, and what is the mission of Westcore?"},
#   {'timestamp': (8.0, 12.0),
#    'text': " Well, Westcore, by the way, stands for Women's Economic Self-Sufficiency Team."},
#   {'timestamp': (12.0, 17.0),
#    'text': ' Our basic mission is to work with low-income women and minorities'},
#   {'timestamp': (17.0, 20.0),
#    'text': ' who want to either start or grow their own business.'},
#   {'timestamp': (20.0, 22.0),
#    'text': ' I should mention, though, that we do serve men as well.'},
#   {'timestamp': (22.0, 24.0), 'text': " That's a common misconception."},
#   {'timestamp': (24.0, 27.0),
#    'text': ' But we principally target our services to women'},
#   {'timestamp': (0.0, 5.0),
#    'text': " to women because I think it's fair to say that poverty in this country, and it's certainly"},
#   {'timestamp': (5.0, 12.0),
#    'text': ' true in New Mexico, has a female face. And we work with individuals who want to either'},
#   {'timestamp': (12.0, 17.0),
#    'text': ' start or grow their own business, and our credit program is one aspect. We certainly,'},
#   {'timestamp': (17.0, 23.0),
#    'text': ' I would say, place more emphasis on training and business assistance to clients because'},
#   {'timestamp': (23.0, 27.0),
#    'text': ' many of the individuals that we work with are wanting to start a business, but they'},
#   {'timestamp': (0.0, 5.68),
#    'text': ' come to us with little or no business background. So before we offer them a credit or they have'},
#   {'timestamp': (5.68, 11.96),
#    'text': " access to our loan fund, we'd like to make sure that they are aware of what they're getting"},
#   {'timestamp': (11.96, 15.02), 'text': ' into and what their risks are.'},
#   {'timestamp': (15.02, 19.98),
#    'text': " Are you finding that a lot of the women that you're lending money to are serious about"},
#   {'timestamp': (19.98, 23.68),
#    'text': " their enterprises and what they're doing and that they are serious about returning the"},
#   {'timestamp': (23.68, 25.32), 'text': ' loan and paying it back on time?'},
#   {'timestamp': (0.0, 5.04),
#    'text': " Yeah, I think there's quite an entrepreneurial spirit here in New Mexico,"},
#   {'timestamp': (5.44, 11.64),
#    'text': " and I often say it's because it's not that entrepreneurism is something nice to think about,"},
#   {'timestamp': (11.74, 16.92),
#    'text': " but for a lot of low-income people, it's often the alternative to a minimum wage paying job."},
#   {'timestamp': (17.6, 25.38),
#    'text': ' And again, our goal is just to help educate that client to make sure that he or she really understands'},
#   {'timestamp': (25.38, 27.62),
#    'text': ' what it is they want to do in their business,'},
#   {'timestamp': (0.0, 7.28),
#    'text': " And if they're going to get a loan to help them understand how it is that they're going to be able to pay it back."},
#   {'timestamp': (7.44, 13.46),
#    'text': " So we really work with them on building the skills that they're going to need to run a successful business."},
#   {'timestamp': (13.78, 17.5),
#    'text': ' Senator Bingaman, what do you think about these efforts here that are going on in New Mexico?'},
#   {'timestamp': (18.1, 19.2), 'text': " Well, I think they're terrific."},
#   {'timestamp': (19.74, 26.14),
#    'text': ' We clearly have a group of people who are low-income, moderate-income people'},
#   {'timestamp': (0.0, 7.0),
#    'text': ' who do not have the ability to get the credit they need through traditional institutions,'},
#   {'timestamp': (7.0, 12.5),
#    'text': ' banks primarily, and therefore something like these micro-lending institutions is filling'},
#   {'timestamp': (12.5, 14.72), 'text': ' that need.'},
#   {'timestamp': (14.72, 21.42),
#    'text': ' As I see it, the real advantage is this is the lending of funds to these entrepreneurs'},
#   {'timestamp': (21.42, 27.18),
#    'text': ' is one of many services that need to be provided for them to succeed, and the others have been'},
#   {'timestamp': (0.0, 5.64),
#    'text': ' mentioned here, training and just general information about how to set up a business,'},
#   {'timestamp': (5.76, 10.92),
#    'text': ' how to make it prosper, how to meet a payroll, do the things that are required.'},
#   {'timestamp': (11.22, 17.52),
#    'text': " I think clearly there's a lot of opportunity for job creation in our state by these micro-enterprises."},
#   {'timestamp': (18.02, 24.5),
#    'text': " And so the micro-lending that is being done to the micro-enterprises is exactly what's needed."},
#   {'timestamp': (24.78, 29.2),
#    'text': ' In terms of economic development in the state of New Mexico and, as you know, in some of the rural areas,'},
#   {'timestamp': (0.0, 3.84),
#    'text': ' there is not that opportunity in small communities for economic development.'},
#   {'timestamp': (4.02, 10.98),
#    'text': ' How important is it that organizations like those that are here today, that they succeed?'},
#   {'timestamp': (11.86, 13.16), 'text': " Well, I think it's very important."},
#   {'timestamp': (13.16, 19.5),
#    'text': " We have, we're putting in place and have in recent years put in place some assistance to small businesses"},
#   {'timestamp': (19.5, 26.26),
#    'text': " throughout the state, the small business development centers, which we've got a great many of around the state."},
#   {'timestamp': (0.66, 6.22),
#    'text': " I think they provide a real service, but again, they don't have the funds to lend."},
#   {'timestamp': (6.94, 8.76), 'text': ' They can do some of the training.'},
#   {'timestamp': (8.92, 10.48),
#    'text': ' They can provide some of the advice.'},
#   {'timestamp': (11.24, 16.2),
#    'text': ' But particularly in small communities, as you point out, there is a real need,'},
#   {'timestamp': (16.2, 19.9),
#    'text': ' and I think these organizations are filling that need,'},
#   {'timestamp': (20.12, 23.7),
#    'text': ' and so our state benefits tremendously from it.'},
#   {'timestamp': (24.24, 25.8), 'text': ' Let me ask you one more question.'},
#   {'timestamp': (25.9, 29.78),
#    'text': ' Is there a bipartisan consensus forming in Washington on this issue?'},
#   {'timestamp': (0.0, 1.28), 'text': ' What is the mood there?'},
#   {'timestamp': (1.38, 6.98),
#    'text': " Well, I think realistically this issue hasn't gotten the airing that it deserves in Washington."},
#   {'timestamp': (7.22, 8.32), 'text': ' We did introduce a bill.'},
#   {'timestamp': (8.5, 10.46), 'text': ' Senator Kennedy sponsored a bill.'},
#   {'timestamp': (11.2, 12.14), 'text': ' I co-sponsored.'},
#   {'timestamp': (12.24, 13.8), 'text': ' Senator Domenici co-sponsored.'},
#   {'timestamp': (13.8, 21.54),
#    'text': " So there's clearly bipartisan support for doing something at the federal level to assist these micro-lenders"},
#   {'timestamp': (21.54, 25.9),
#    'text': ' or these organizations that are assisting micro-enterprises.'},
#   {'timestamp': (26.52, 28.74), 'text': ' But we need to have some hearings.'},
#   {'timestamp': (0.0, 5.18),
#    'text': ' We need to, in the new Congress, we need to have hearings, and we need to get more attention to this.'},
#   {'timestamp': (5.24, 12.7),
#    'text': " I think there's been much more attention in Washington to the benefits from micro-lending in the international arena"},
#   {'timestamp': (12.7, 15.68),
#    'text': ' than there has been to micro-lending here in our own country.'},
#   {'timestamp': (16.12, 17.16), 'text': ' Let me go to Marisa.'},
#   {'timestamp': (17.32, 24.04),
#    'text': ' Marisa, how important do you think these organizations, an organization like yours is, to help fight poverty?'},
#   {'timestamp': (24.64, 26.26), 'text': ' I think they are very important.'},
#   {'timestamp': (26.38, 29.16),
#    'text': " I think it's dangerous to see them as the sole strategy."},
#   {'timestamp': (0.0, 7.16),
#    'text': " I'm glad to hear the senator underscore some of the different components in making microloans really a successful strategy,"},
#   {'timestamp': (7.34, 11.58),
#    'text': ' and that involves training as well as other community support services.'},
#   {'timestamp': (12.14, 17.06),
#    'text': ' But at Accion, New Mexico, while our loans are small, the average loan size is right around $1,200,'},
#   {'timestamp': (17.82, 20.48),
#    'text': ' although we do offer loans up to $50,000,'},
#   {'timestamp': (21.12, 27.52),
#    'text': ' those loans have produced an enormous impact in the lives of the individual entrepreneurs and their families,'},
#   {'timestamp': (0.0, 2.4),
#    'text': ' and I think most importantly in the community.'},
#   {'timestamp': (2.4, 8.7),
#    'text': ' We, about a year and a half ago, did a statistical study of the impact of our loans'},
#   {'timestamp': (8.7, 13.5),
#    'text': ' and found that on average, after just two loans with our program,'},
#   {'timestamp': (13.5, 20.1),
#    'text': ' that business saw an increase in revenue of around 60% of business revenue,'},
#   {'timestamp': (20.1, 23.2),
#    'text': ' an increase in business assets of 70%,'},
#   {'timestamp': (23.2, 28.9),
#    'text': ' and really amazingly, an increase in take-home income for that entrepreneur of almost 90%,'},
#   {'timestamp': (0.0, 1.4), 'text': ' of 87%.'},
#   {'timestamp': (1.4, 5.48),
#    'text': ' So how do you get in touch with your clients, or do your clients get in touch with you?'},
#   {'timestamp': (5.92, 9.2),
#    'text': " I think at this point it's a little bit of both, but that remains a challenge."},
#   {'timestamp': (9.66, 15.22),
#    'text': ' I think any non-profit is faced with how to really market and conduct outreach on a limited budget.'},
#   {'timestamp': (15.88, 18.42),
#    'text': ' So for us, we rely quite a bit on word of mouth.'},
#   {'timestamp': (18.54, 23.74),
#    'text': ' A lot of our clients feel good enough about the program that they really want to share the word with their friends'},
#   {'timestamp': (23.74, 26.26),
#    'text': ' and see them access the same opportunities.'},
#   {'timestamp': (0.0, 6.32),
#    'text': ' So word of mouth is probably our primary way of reaching entrepreneurs in the Albuquerque area.'},
#   {'timestamp': (6.82, 13.2),
#    'text': " Whenever possible, you know, we'll do radio and TV interviews such as this to try and spread the word in the public."},
#   {'timestamp': (13.98, 15.34),
#    'text': ' Vanjie, I want to ask you a question.'},
#   {'timestamp': (15.44, 20.74),
#    'text': ' What kind of an impact do you think that microlenders have on the battle against poverty?'},
#   {'timestamp': (21.38, 28.76),
#    'text': " Well, I think in New Mexico, these three organizations, and I'll speak, I'll let Westcore and Acción speak for themselves,"},
#   {'timestamp': (0.0, 5.8),
#    'text': " but I know that we've all collectively had a big impact in the poverty in New Mexico."},
#   {'timestamp': (5.8, 11.8),
#    'text': ' We primarily serve the rural areas of New Mexico where the poverty rates are higher than in the urban areas.'},
#   {'timestamp': (11.8, 16.8),
#    'text': " We've done work in Mora and we've done work in Tierra Maria,"},
#   {'timestamp': (16.8, 22.5),
#    'text': ' and these are really counties and communities that have a very high poverty rate.'},
#   {'timestamp': (22.5, 24.5), 'text': ' And we have made an impact.'},
#   {'timestamp': (24.5, 29.3),
#    'text': " We have created in excess of a thousand jobs in our history, and we're nine years old."},
#   {'timestamp': (0.0, 2.0), 'text': ' into our 10th year.'},
#   {'timestamp': (2.0, 8.0),
#    'text': " We've made in excess of 250 loans and we have,"},
#   {'timestamp': (8.0, 12.0),
#    'text': ' our success rate in terms of repayment is less than 1%'},
#   {'timestamp': (12.0, 14.0), 'text': ' or default rate.'},
#   {'timestamp': (14.0, 17.0),
#    'text': " And we've loaned practically $5 million."},
#   {'timestamp': (17.0, 21.0),
#    'text': ' I think that not only have we made an impact in creating jobs'},
#   {'timestamp': (21.0, 27.0),
#    'text': ' that are sustainable jobs over time and providing assistance'},
#   {'timestamp': (0.0, 6.6),
#    'text': ' assistance to businesses that are also sustaining themselves over time, which helps the community,'},
#   {'timestamp': (6.6, 9.94),
#    'text': ' which helps the business owner, and which helps the people that they hire.'},
#   {'timestamp': (9.94, 14.84),
#    'text': ' One of our criteria is that if there is going to be any job creation, that that job creation'},
#   {'timestamp': (14.84, 20.58),
#    'text': ' is offered to low-income individuals within that community, and that the salaries that'},
#   {'timestamp': (20.58, 22.72), 'text': ' they pay are sustainable salaries.'},
#   {'timestamp': (22.72, 27.66),
#    'text': " We don't want our loans to continue to create more working poor."},
#   {'timestamp': (0.0, 5.78),
#    'text': ' We want to make sure that the people who get those jobs have a livable wage so they can'},
#   {'timestamp': (5.78, 10.82),
#    'text': ' stay within their communities and support other economic development within those communities.'},
#   {'timestamp': (10.82, 14.18),
#    'text': " I think we're having a major impact."},
#   {'timestamp': (14.18, 19.42),
#    'text': ' Poverty rates seem to be going up rather than going down, but we look at each individual'},
#   {'timestamp': (19.42, 25.42),
#    'text': ' community where we work and we look at the statistics within those communities and we'},
#   {'timestamp': (0.0, 5.22),
#    'text': ' We have seen that we have created an impact in those communities.'},
#   {'timestamp': (5.22, 11.88),
#    'text': " You've worked with clients and you see that this is making a change in their life."},
#   {'timestamp': (11.88, 17.98),
#    'text': ' What kind of stories can you tell me about people who have come and gotten loans?'},
#   {'timestamp': (17.98, 19.98), 'text': " It's amazing."},
#   {'timestamp': (19.98, 23.04),
#    'text': ' I guess I have a couple of favorites.'},
#   {'timestamp': (23.04, 28.8),
#    'text': ' Certainly the young man in Santa Fe, Kevin Bellinger, who started Harambe and works with'},
#   {'timestamp': (0.0, 7.0),
#    'text': " at-risk youth. He's a young man who was also involved with gangs and at-risk himself and"},
#   {'timestamp': (7.36, 13.5),
#    'text': ' has started this program to get kids interested through art and performance to get them off'},
#   {'timestamp': (13.5, 20.5),
#    'text': ' the streets and put them in a much different direction in their lives. And just to talk'},
#   {'timestamp': (21.94, 27.82),
#    'text': ' to those kids and their enthusiasm and their new interest in doing something else other'},
#   {'timestamp': (0.0, 2.32),
#    'text': ' than be out in the street and getting into trouble.'},
#   {'timestamp': (2.32, 3.26), 'text': " It's just amazing."},
#   {'timestamp': (3.96, 7.28),
#    'text': " And one of the other ones that I just, it's one of my favorites,"},
#   {'timestamp': (7.44, 11.32),
#    'text': " it's in a low-income area in Albuquerque."},
#   {'timestamp': (12.34, 16.12),
#    'text': ' And it is a cooperative of 25 very low-income women,'},
#   {'timestamp': (16.74, 18.6), 'text': ' primarily Spanish-speaking women,'},
#   {'timestamp': (18.78, 22.22),
#    'text': ' who got together and started a sewing cooperative four years ago.'},
#   {'timestamp': (22.72, 26.32),
#    'text': ' And these women were very extremely shy,'},
#   {'timestamp': (0.0, 7.24),
#    'text': ' very traditional roles of staying at home, raising their families, and ventured out'},
#   {'timestamp': (7.24, 10.14),
#    'text': ' because they wanted to improve their quality of life.'},
#   {'timestamp': (11.04, 18.0),
#    'text': ' And the change in the women themselves, their own attitude around self-reliance'},
#   {'timestamp': (18.0, 23.7),
#    'text': ' and their confidence in themselves has changed dramatically over four years.'},
#   {'timestamp': (24.18, 26.42),
#    'text': " Four years ago, these women wouldn't talk in public,"},
#   {'timestamp': (26.42, 29.82),
#    'text': ' and now they can go and tell their story and tell it well.'},
#   {'timestamp': (0.0, 1.8), 'text': " and they're doing an incredible job."},
#   {'timestamp': (1.8, 6.38),
#    'text': ' And 25 women have stuck with this project for over four years'},
#   {'timestamp': (6.38, 7.9), 'text': ' and continue to do very well.'},
#   {'timestamp': (8.4, 9.64), 'text': ' So those are the kinds of things,'},
#   {'timestamp': (9.64, 11.38),
#    'text': " those are the kinds of impacts we're having,"},
#   {'timestamp': (11.38, 13.28), 'text': ' the kinds of success stories.'},
#   {'timestamp': (13.28, 17.22),
#    'text': ' And we have over 200 stories we could tell.'},
#   {'timestamp': (17.22, 19.86),
#    'text': ' And, you know, not all of them are successful.'},
#   {'timestamp': (19.86, 21.78), 'text': ' We have lost about three loans'},
#   {'timestamp': (21.78, 23.46),
#    'text': ' over the course of our 10-year history.'},
#   {'timestamp': (24.0, 28.32),
#    'text': " But when you look at the statistic, that's not, you know,"},
#   {'timestamp': (0.0, 2.04), 'text': " that's a very small default rate."},
#   {'timestamp': (2.04, 3.74), 'text': ' And people are successful.'},
#   {'timestamp': (3.74, 4.7), 'text': " They're staying in business."},
#   {'timestamp': (4.7, 8.84),
#    'text': ' And, you know, they facilitate other economic development activity.'},
#   {'timestamp': (8.84, 13.44),
#    'text': ' Agnes, I wanted to talk to you about, in general, about microlending.'},
#   {'timestamp': (13.44, 17.46),
#    'text': " What do you think would be the outcome or how some of the clients that you've dealt with,"},
#   {'timestamp': (17.46, 20.36),
#    'text': ' I would imagine that you would hate to think of them not actually getting a loan'},
#   {'timestamp': (20.36, 23.7),
#    'text': " and being able to prosper and do what they're able to do."},
#   {'timestamp': (23.7, 28.56),
#    'text': " How important is microlending to some of the people that you've dealt with?"},
#   {'timestamp': (0.0, 2.5),
#    'text': " and I'm sure that it would apply to everybody else here too."},
#   {'timestamp': (3.22, 7.56),
#    'text': " Well, I think it's critical for the clients that we serve"},
#   {'timestamp': (7.56, 12.22),
#    'text': " because by kind of their very nature that they're low income,"},
#   {'timestamp': (13.04, 18.06),
#    'text': " I would say it's probably true that most can't walk into a bank"},
#   {'timestamp': (18.06, 20.58),
#    'text': ' and have access to a small business loan.'},
#   {'timestamp': (20.58, 23.24),
#    'text': ' So if they have some kind of entrepreneurial dream,'},
#   {'timestamp': (24.22, 27.62),
#    'text': " they're just not going to get access to credit."},
#   {'timestamp': (0.0, 9.94),
#    'text': ' So were it not for the microlending agencies in New Mexico, I think it would be next to impossible for thousands of people to start any kind of small enterprise.'},
#   {'timestamp': (10.58, 15.8),
#    'text': " So, you know, in terms of access to credit, it's absolutely critical."},
#   {'timestamp': (16.22, 21.26),
#    'text': " But I guess one thing I would emphasize, that it's not just access to credit."},
#   {'timestamp': (22.02, 27.52),
#    'text': ' I know when we hear about some of the international examples, we hear microcredit, microcredit, microcredit.'},
#   {'timestamp': (0.0, 7.34),
#    'text': ' The access is important, but I think just as important, especially in a sophisticated economy like the United States.'},
#   {'timestamp': (8.0, 17.8),
#    'text': ' It has to be also a focus on the training, the business assistance to that individual so that they have some chance of success with their business.'},
#   {'timestamp': (18.62, 27.22),
#    'text': ' It would be too easy to hand somebody a loan and say goodbye and good luck and hope that they can make their way through what are going to be some very tough years ahead of them.'},
#   {'timestamp': (0.0, 8.58),
#    'text': " So I know as far as West Corps is concerned, we actually feel that it's the training and the technical assistance that should come first."},
#   {'timestamp': (8.86, 12.42),
#    'text': ' Senator Bingaman, is there legislation in Washington right now?'},
#   {'timestamp': (12.54, 15.74),
#    'text': ' Are you working on any kind of legislation that will help organizations like these succeed?'},
#   {'timestamp': (16.64, 23.4),
#    'text': " Well, yes. This bill that I mentioned, Senator Kennedy introduced, and I'm co-sponsoring, Senator Domenici's co-sponsoring."},
#   {'timestamp': (23.4, 28.64),
#    'text': " It's a bill that we were not able to pass in the Congress that recently adjourned,"},
#   {'timestamp': (0.0, 3.84),
#    'text': " but I'm sure it'll be introduced early in the new Congress."},
#   {'timestamp': (4.08, 8.54),
#    'text': " I think we'll have a much better chance in the new Congress of actually getting it enacted."},
#   {'timestamp': (8.96, 10.14), 'text': ' What is the bill actually?'},
#   {'timestamp': (10.24, 16.26),
#    'text': ' Well, the bill tries to provide some level of federal assistance to organizations'},
#   {'timestamp': (16.26, 23.26),
#    'text': ' like the three that are represented here so that they can do a better job'},
#   {'timestamp': (23.26, 26.42),
#    'text': ' of getting their services out and making these loans'},
#   {'timestamp': (0.0, 4.74),
#    'text': ' and providing this training and assistance to small businesses or micro enterprises.'},
#   {'timestamp': (5.18, 11.24),
#    'text': ' But also it tries to encourage other organizations, other nonprofit organizations,'},
#   {'timestamp': (11.24, 16.58),
#    'text': ' to take up this same kind of a mission so that in all communities,'},
#   {'timestamp': (16.68, 19.26),
#    'text': ' the ideal would be that in all communities in this country,'},
#   {'timestamp': (19.88, 24.48),
#    'text': ' this kind of a resource would be available to people, small entrepreneurs,'},
#   {'timestamp': (0.0, 3.98),
#    'text': ' that were not able to get traditional credit'},
#   {'timestamp': (3.98, 6.42),
#    'text': ' and wanted to go ahead and start a business.'},
#   {'timestamp': (7.1, 8.86),
#    'text': " Well, I guess that's where I have to leave it."},
#   {'timestamp': (8.9, 9.48), 'text': " We're out of time."},
#   {'timestamp': (9.92, 11.74),
#    'text': ' Thank you, everyone, for joining us today.'},
#   {'timestamp': (12.44, 14.2),
#    'text': " And that's our report for this evening."},
#   {'timestamp': (14.36, 16.6),
#    'text': " From all of us at KNME, I'm Arcee Chapa."},
#   {'timestamp': (16.9, 17.92), 'text': ' Thank you for joining us.'},
#   {'timestamp': (19.72, 22.28),
#    'text': ' If you would like to contact us here at In Focus,'},
#   {'timestamp': (0.0, 8.38),
#    'text': ' you can reach us on our website at www.pbs.org.knme'},
#   {'timestamp': (8.38, 15.96),
#    'text': ' or at our email address at infocus at knme1.unm.edu.'},
#   {'timestamp': (0.0, 29.98), 'text': ' Thank you.'},
#   {'timestamp': (0.0, 29.98), 'text': ' Thank you.'}]}
